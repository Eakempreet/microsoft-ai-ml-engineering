# %% [markdown]
# # **Foundations of AI and Machine Learning** 🤖

# %% [markdown]
# ## **1. Azure ML Pipeline: Store → Prep → Build → Serve → Watch**
# #### 1. STORE (where data lives)
#
# **Azure Data Lake Storage**
# > Think: a warehouse dumping ground for messy stuff like images, logs, anything unstructured.
#
# Formal: Scalable cloud storage for large volumes of raw, unstructured, or semi-structured data.
#
# **Azure SQL Database**
# > Think: a neat filing cabinet, clean rows and columns, like your metadata CSV.
#
# Formal: Fully managed relational database service for structured, queryable data.
#
# #### 2. PREP (get data ready)
#
# **Azure Data Factory**
# > Think: the plumber, moves data from A to B on a schedule, no processing.
#
# Formal: Cloud based ETL(Extract, Transform, Load)/orchestration service for moving and scheduling data between systems.
#
# **Azure Databricks**
# > Think: the muscle, heavy cleaning/transforming of huge datasets.
#
# Formal: Apache Spark based analytics platform for large scale data processing and transformation.
#
# #### 3. BUILD (create the model)
#
# **TensorFlow**
# > Think: the toolbox you build the neural network with.
#
# Formal: Open source deep learning framework used to build and train neural networks.
#
# **Azure Machine Learning Service**
# > Think: the control room, manages the whole ML lifecycle in one place.
#
# Formal: Managed cloud platform for the end to end ML lifecycle (training, registry, deployment, monitoring).
#
# **Azure Machine Learning SDK**
# > Think: your Python remote control into that control room.
#
# Formal: Python library for interacting with Azure ML Service programmatically.
#
# #### 4. SERVE (deploy as a web service)
#
# **Azure App Services**
# > Think: HF Spaces equivalent, simple hands off web app hosting.
#
# Formal: Managed PaaS(Platform as a Service) for hosting web applications/APIs, including ML models, without managing infrastructure.
#
# **Azure Kubernetes Service (AKS)**
# > Think: hosting at massive scale, many containers, load balanced, auto healing.
#
# Formal: Managed container orchestration (the automated coordination, scheduling, and management of complex data pipelines and tasks across multiple systems) service for deploying and scaling containerized apps at scale.
#
# #### 5. WATCH (keep it healthy)
#
# **Azure Monitor**
# > Think: the watchdog, flags you the moment something breaks.
#
# Formal: Service for collecting, analyzing, and acting on telemetry (logs, metrics, alerts).
#
# ---

# %% [markdown]
# ## **2. DATA**
#
# ### **1. Data Pipelines**
#
# To unlock valuable insights and make accurate predictions, your models need high-quality, well-prepared data. This is where data pipelines and sources become essential.
#
# > A well-designed data pipeline keeps your data clean, organized, and analysis-ready.
#
#
# ### **2. Data Sources**
#
# **Data sources = the origins where your project's data comes from before it enters any pipeline.**
#
# **Formal definition:** Data sources are the origins from which you gather the data needed for AI/ML projects, ranging from structured databases to unstructured data (images, text) to real-time streams from sensors or APIs.
#
# **Analogy:** Think of it like ingredients before cooking some come pre-chopped in labeled containers (structured), some are raw and messy (unstructured), some arrive fresh and continuously (real-time streams). Where you source them shapes how you prep them.
#
# **The four types, for your notes:**
#
# | **Type** | **Examples** | **Structure** |
# |---|---|---|
# | **Relational databases** | SQL Server, MySQL, PostgreSQL | Fixed schema, tables/rows/columns, queried via SQL |
# | **NoSQL databases** | Azure Cosmos DB, MongoDB | Unstructured/semi-structured, flexible schema, key-value, document, or graph formats |
# | **Cloud storage** | Azure Blob Storage, Amazon S3 | Scalable storage for large unstructured data (images, video, backups) |
# | **Real-time streams** | IoT sensors, social media APIs | Continuous data, processed live for immediate insights |
#
# **Why it matters:** the type of data source you're pulling from determines how you design the rest of the pipeline (ingestion method, storage choice, processing tools) it's the first decision point, not just a background detail.
#
# ### **3. What is a Data Pipeline?**
#
# **Formal definition:** A data pipeline is a series of automated processes that move data from its source to a destination, transforming it along the way to prepare it for analysis or machine learning.
#
# **Analogy:** A conveyor belt in a factory. Raw, unprocessed data enters the pipeline, moves through stages of transformation, and exits as clean, organized information ready for use.
#
#
# ### **4. Key Stages of a Data Pipeline**
#
# - **Stage 1: Data Ingestion**
#     **Role:** First stage, where raw data is collected from various sources. Can happen in real time (streaming) or in batches (bulk transfers), depending on the nature of the data and project requirements.
#
#     **Tool:** Azure Data Factory. Connects to a wide range of sources (on prem databases, cloud storage, APIs), schedules and automates transfers to keep the pipeline up to date.
#
# - **Stage 2: Data Processing / Transformation**
#     **Role:** Raw ingested data is processed and transformed to make it suitable for analysis or model training: cleaning (removing duplicates, filling missing values), normalizing (scaling numerical values), transforming (aggregating data, joining tables).
#
#     **Tool:** Azure Databricks. Collaborative environment built on Apache Spark, for large scale data processing and complex transformations.
#
# - **Stage 3: Data Storage**
#     **Role:** After processing, data is stored where it can be easily accessed by data analysts, data scientists, and AI/ML models. Storage choice depends on data type and downstream use.
#
#     **Tools:**
#     **Azure Data Lake Storage:** optimized for vast amounts of raw, unstructured data
#     **Azure SQL Database:** ideal for structured data needing advanced querying
#     **Azure Blob Storage:** versatile storage for unstructured data (text, images, video)
#
# - **Stage 4: Data Access and Utilization**
#     **Role:** Final stage. Processed, stored data is made available for analysis or as input into ML models. Data scientists and engineers use it to train models, generate reports, or drive decisions.
#
#     **Tools:** Azure Machine Learning Service (model training), Power BI (business analytics)
#
#
# ### **5. Role of Data Pipelines in AI/ML Projects**
#
# - Pipeline quality and reliability directly impact model performance
# - A well structured pipeline means consistent, accurate, up to date data, resulting in reliable, effective models
# - A weak pipeline means models trained on flawed data, leading to poor predictions and costly mistakes
# - **Scalability:** a well designed pipeline handles growing data volume and variety, letting AI/ML systems scale. This is a competitive advantage in modern projects
#
#
# ### **6. Types of ML Using Data Pipelines**
#
# | **Type** | **Data Used** | **Goal** |
# |---|---|---|
# | **Supervised learning** | Labeled data (input output pairs) | Learn from known outcomes: classification, regression |
# | **Unsupervised learning** | Unlabeled data | Find patterns/groupings (clustering, association), exploratory, hidden structure |
# | **Reinforcement learning** | No fixed dataset, agent + environment | Learn via trial and error, maximizing rewards: game playing, robotics |
#
# **Note:** which type you use depends on labeled data availability and task complexity.
#
#
# ### **AzureEvent Hubs:**
#
# **Analogy**: A high speed mail sorting facility that never stops, built to catch millions of letters flying in every second without dropping any.
#
# **Formal definition**: Azure Event Hubs is a real time data ingestion service designed for high throughput data streaming, capable of capturing millions of events per second from devices, applications, and services.
#
# ---

# %% [markdown]
# ## **3. ML Frameworks Comparison**
#
# | Framework | Type | Key Features | Best For |
# |---|---|---|---|
# | **TensorFlow** | Deep learning | Eager + graph execution, scales on CPU/GPU/TPU, TensorFlow Serving | Image recognition, NLP, reinforcement learning |
# | **PyTorch** | Deep learning | Dynamic computation graphs, Pythonic, TorchScript for deployment | Research, prototyping, computer vision, NLP (Transformers) |
# | **Scikit-learn** | Traditional ML | Simple API, wide algorithm range, built in evaluation tools | Predictive modeling, data preprocessing, model evaluation |
# | **Azure ML SDK** | Cloud/enterprise ML | AutoML, Azure integration, experiment tracking, scalable deployment | Enterprise AI, AutoML, model monitoring |

# %% [markdown]
# ## **4. Handling data**
#
# ### **4.1 SQL for Data Acquisition**
#
# **SELECT**
# Pulls specific columns from a table.
# `SELECT name, email FROM customers WHERE country = 'US';`
#
# **WHERE**
# Filters rows by a condition.
# `SELECT * FROM orders WHERE order_date > '2024-01-01';`
#
# **JOIN**
# Combines rows from two tables using a shared column.
# - INNER JOIN: only matching rows in both tables
# - LEFT JOIN: all rows from left table, matched or NULL from right
# - RIGHT JOIN: all rows from right table, matched or NULL from left
# - FULL JOIN: all rows from both, matched or not
#
# **GROUP BY + Aggregation**
# Groups rows and summarizes with COUNT, SUM, AVG, MIN, MAX.
# `SELECT product_id, COUNT(*) FROM sales GROUP BY product_id;`
#
# **ORDER BY**
# Sorts results. ASC (default) or DESC.
#
# **INSERT / UPDATE / DELETE**
# INSERT adds a row. UPDATE modifies a row. DELETE removes a row.
#
# **Subquery**
# A query nested inside another query, used when one filter depends on the result of another lookup.
#
# **Indexing**
# Speeds up lookups on a column by keeping a sorted pointer to it. Costs a bit on write speed.
#
# **Transactions (ACID)**
# A group of SQL operations treated as one unit, either all succeed or none do. Keeps data consistent during multi-step operations like transfers.

# %% [markdown]
# ### **4.2 Web Scrapping**
#
# Web scraping is a powerful method for acquiring data from websites, especially when the information you need isn’t readily available in a structured format. By setting up a web scraper in your local environment, you can automate the process of gathering large amounts of data from the web.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


# Send request to the webpage
url = 'https://en.wikipedia.org/wiki/Cloud-computing_comparison'

# This header makes our request look like it's coming from a real Chrome browser
# instead of Python's default, which some servers (like Wikipedia) block
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/151.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
# requests.get(url) does what your browser does when you type a URL and hit enter, it sends an HTTP request to that server and asks for the page. The server sends back the raw HTML of the page, and that gets stored in response
# response isn't the parsed page, it's the raw response object: status code, headers, and the HTML content all bundled together


# 200 = success, anything else means the request was blocked or failed
if response.status_code==200:
    print(f"{response.status_code}, Request Successful.")
else:
    print(f"{response.status_code}, Request Unsuccessful. Failed to retrieve the webpage.")
# Out:
# 200, Request Successful.

# %% [markdown]
# - When you run `requests.get(url)` with no headers specified, the requests library still sends headers, it just fills in its own defaults. One of those defaults is:
#
#     ```python
#     User-Agent: python-requests/2.31.0
#     ```
#     > **Means:** "I am a Python script, version 2.31.0 of the requests library. Any server can read that header and immediately know you're not a browser
#
# - An HTTP request isn't just "give me this page," it's a request with a bunch of metadata attached, sent as key-value pairs called headers. A few common ones:
#
#   - **User-Agent**: who's asking (browser name, OS, version). This is the one that got you blocked.
#   - **Accept**: what content types you're willing to receive (HTML, JSON, images, etc.)
#   - **Referer**: what page you clicked from to get here
#   - **Cookie**: session/login data, if any
#
# - We're overriding just the `User-Agent` key so the server sees a string that matches what real Chrome sends, instead of `python-requests/2.31.0`. The server has no way to actually verify this, it just trusts the header, so this works by presenting a claim the server doesn't cross-check.
#
# ---
#
# - `Mozilla/5.0`                → legacy tag, every browser still says this
# - `AppleWebKit/537.36`         → rendering engine (used by Chrome & Safari)
# - `(KHTML, like Gecko)`        → old compatibility claims (WebKit's ancestor + Firefox's engine)
# - `Chrome/151.0.0.0`           → the real signal: this is Chrome, version 151
# - `Safari/537.36`              → kept for WebKit compatibility checks

# %%
# Raw HTML content fetched
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-feature-navigation-update-disabled vector-sticky-header-enabled vector-toc-available skin-thumbsize-clientpref-standard" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Cloud-computing comparison - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-feature-navigation-update-disabled vector-sticky-header-enabled vector-toc-available skin-thumbsize-clientpref-standard";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"f8a80f8b-15b7-46a8-a1a6-eb7d599f65d9","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Cloud-computing_comparison","wgTitle":"Cloud-computing comparison","wgCurRevisionId":1365802661,"wgRevisionId":1365802661,"wgArticleId":33529756,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","CS1 maint: deprecated archival service","Webarchive template wayback links","Cloud computing","Cloud platforms","Computing comparisons"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Cloud-computing_comparison","wgRelevantArticleId":33529756,"wgTempUserName":null,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgConfirmEditCaptchaNeededForGenericEdit":"hcaptcha","wgConfirmEditForceShowCaptcha":false,"wgConfirmEditHCaptchaSiteKey":"5d0c670e-a5f4-4258-ad16-1f42792c9c62","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgMediaViewerMobileBeta":false,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":20000,"wgParsoidHtmlVersion":"2.8.0","parsermigration-parsoid":true,"wgPageAssessments":{"Computing":{"class":"Start","importance":"Mid"},"Project-independent assessment":{"class":"Start","importance":""}},"wgTestKitchenUserExperiments":{"overrides":[],"enrolled":[],"assigned":[],"subject_ids":[]},"wgEditSubmitButtonLabelPublish":true,"wgVisualEditorPageIsDisambiguation":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageIn ...

# %%
# Turn the raw HTML text into a structured object we can search through
soup = BeautifulSoup(response.content, 'html.parser')
#'html.parser' just tells it which parsing engine to use, Python's built-in one, no extra install needed.

# Print the page title to confirm we parsed the right page
print("Title: " + soup.title.text)
# Out:
# Title: Cloud-computing comparison - Wikipedia

# %%
# Wikipedia data tables usually have the class "wikitable"
table = soup.find('table', {'class': 'wikitable'})

# Check if we actually found one 
print(table is not None)

print(table)
# Out:
# True
# <table class="wikitable sortable" id="mwCw">
# <tbody id="mwDA"><tr id="mwDQ">
# <th id="mwDg">Provider</th>
# <th id="mwDw">Launched</th>
# <th id="mwEA">Block storage</th>
# <th id="mwEQ">Assignable IPs</th>
# <th id="mwEg">SMTP support</th>
# <th id="mwEw">IOPS <small id="mwFA">Guaranteed minimum</small></th>
# <th id="mwFQ"><a href="https://en.wikipedia.org/wiki/Computer_security" id="mwFg" rel="mw:WikiLink" title="Computer security">Security</a></th>
# <th id="mwFw"><a href="https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes" id="mwGA" rel="mw:WikiLink" title="List of ISO 3166 country codes">Locations</a></th>
# <th id="mwGQ">Notes</th></tr>
# <tr id="mwGg">
# <td id="mwGw"><a href="https://en.wikipedia.org/wiki/Google_Cloud_Platform" id="mwHA" rel="mw:WikiLink" title="Google Cloud Platform">Google Cloud Platform</a></td>
# <td id="mwHQ">2013</td>
# <td about="#mwt2" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwHg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt3" class="table-no" data-mw='{"parts":["| ",{"template":{"target":{"wt":"no","href":"./Template:No"},"params":{},"i":0}}]}' id="mwHw" style="background:#FFC7C7;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">No</td>
# <td about="#mwt4" class="table-no" data-mw='{"parts":["| ",{"template":{"target":{"wt":"no","href":"./Template:No"},"params":{},"i":0}},"&lt;ref&gt;[https://cloud.google.com/compute/docs/tutorials/sending-mail/ SMTP] at Google compute&lt;/ref&gt;"]}' id="mwIA" style="background:#FFC7C7;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">No<sup about="#mwt5" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-1"}}' id="cite_ref-1" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-1" id="mwIQ"><span class="mw-reflink-text" id="mwIg"><span class="cite-bracket" id="mwIw">[</span>1<span class="cite-bracket" id="mwJA">]</span></span></a></sup></td>
# <td about="#mwt6" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwJQ" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt7" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://cloud.google.com/security Security, Privacy, and Cloud Compliance | Google Cloud]&lt;/ref&gt;"]}' id="mwJg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt8" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-2"}}' id="cite_ref-2" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-2" id="mwJw"><span class="mw-reflink-text" id="mwKA"><span class="cite-bracket" id="mwKQ">[</span>2<span class="cite-bracket" id="mwKg">]</span></span></a></sup></td>
# <td id="mwKw">br, ca, cl, us, be, ch, de, es, fi, it, po, nl, uk, il, au, cn, in, jp, sg, id, tw<sup about="#mwt9" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-3"}}' id="cite_ref-3" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-3" id="mwLA"><span class="mw-reflink-text" id="mwLQ"><span class="cite-bracket" id="mwLg">[</span>3<span class="cite-bracket" id="mwLw">]</span></span></a></sup></td>
# <td id="mwMA">SMTP blocked.<sup about="#mwt12" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-4"}}' id="cite_ref-4" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-4" id="mwMQ"><span class="mw-reflink-text" id="mwMg"><span class="cite-bracket" id="mwMw">[</span>4<span class="cite-bracket" id="mwNA">]</span></span></a></sup></td></tr>
# <tr id="mwNQ">
# <td id="mwNg"><a href="https://en.wikipedia.org/wiki/Oracle_Cloud" id="mwNw" rel="mw:WikiLink" title="Oracle Cloud">Oracle Cloud</a></td>
# <td id="mwOA">2014</td>
# <td about="#mwt13" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwOQ" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt14" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwOg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt15" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwOw" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt16" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwPA" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt17" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://www.oracle.com/security/cloud-security/ Cloud Security Services]&lt;/ref&gt;"]}' id="mwPQ" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt18" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-5"}}' id="cite_ref-5" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-5" id="mwPg"><span class="mw-reflink-text" id="mwPw"><span class="cite-bracket" id="mwQA">[</span>5<span class="cite-bracket" id="mwQQ">]</span></span></a></sup></td>
# <td id="mwQg">us, ca, br, de, uk, nl, ch, in, aus, jp, kr, saud</td>
# <td id="mwQw"></td></tr>
# <tr id="mwRA">
# <td id="mwRQ"><a href="https://en.wikipedia.org/wiki/Amazon_Web_Services" id="mwRg" rel="mw:WikiLink" title="Amazon Web Services">Amazon Web Services</a></td>
# <td id="mwRw">2006</td>
# <td about="#mwt19" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwSA" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt20" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwSQ" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt21" class="table-partial" data-mw='{"parts":["| ",{"template":{"target":{"wt":"partial","href":"./Template:Partial"},"params":{},"i":0}},"&lt;ref&gt;[https://aws.amazon.com/premiumsupport/knowledge-center/ec2-port-25-throttle/ Restriction on port 25] at AWS&lt;/ref&gt;"]}' id="mwSg" style="background:#FFB; color:black;vertical-align:middle;text-align:center; " typeof="mw:Transclusion">Partial<sup about="#mwt22" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-6"}}' id="cite_ref-6" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-6" id="mwSw"><span class="mw-reflink-text" id="mwTA"><span class="cite-bracket" id="mwTQ">[</span>6<span class="cite-bracket" id="mwTg">]</span></span></a></sup></td>
# <td about="#mwt23" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwTw" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt24" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://aws.amazon.com/security/ AWS Cloud Security]&lt;/ref&gt;"]}' id="mwUA" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt25" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-7"}}' id="cite_ref-7" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-7" id="mwUQ"><span class="mw-reflink-text" id="mwUg"><span class="cite-bracket" id="mwUw">[</span>7<span class="cite-bracket" id="mwVA">]</span></span></a></sup></td>
# <td id="mwVQ">us, ca, br, ie, de, uk, cn, sg, au, jp, kr, in, za, fr, se, bh, hk, it, id</td>
# <td id="mwVg">List of bugs<sup about="#mwt26" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-8"}}' id="cite_ref-8" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-8" id="mwVw"><span class="mw-reflink-text" id="mwWA"><span class="cite-bracket" id="mwWQ">[</span>8<span class="cite-bracket" id="mwWg">]</span></span></a></sup></td></tr>
# <tr id="mwWw">
# <td id="mwXA"><a href="https://en.wikipedia.org/wiki/IBM_Cloud" id="mwXQ" rel="mw:WikiLink" title="IBM Cloud">IBM Cloud</a></td>
# <td id="mwXg">2005</td>
# <td about="#mwt27" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwXw" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt28" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwYA" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt29" class="table-no" data-mw='{"parts":["| ",{"template":{"target":{"wt":"no","href":"./Template:No"},"params":{},"i":0}},"&lt;ref&gt;[https://cloud.ibm.com/docs/email-delivery?topic=email-delivery-email-delivery-faw SMTP] at IBM&lt;/ref&gt;"]}' id="mwYQ" style="background:#FFC7C7;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">No<sup about="#mwt30" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-9"}}' id="cite_ref-9" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-9" id="mwYg"><span class="mw-reflink-text" id="mwYw"><span class="cite-bracket" id="mwZA">[</span>9<span class="cite-bracket" id="mwZQ">]</span></span></a></sup></td>
# <td about="#mwt31" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwZg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt32" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://www.ibm.com/cloud/security Security for IBM Cloud]&lt;/ref&gt;"]}' id="mwZw" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt33" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-10"}}' id="cite_ref-10" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-10" id="mwaA"><span class="mw-reflink-text" id="mwaQ"><span class="cite-bracket" id="mwag">[</span>10<span class="cite-bracket" id="mwaw">]</span></span></a></sup></td>
# <td id="mwbA">us, gb, fr, de, nl, in, au, hk, kr, it, jp, no, sg</td>
# <td id="mwbQ"></td></tr>
# <tr id="mwbg">
# <td id="mwbw"><a href="https://en.wikipedia.org/wiki/Microsoft_Azure" id="mwcA" rel="mw:WikiLink" title="Microsoft Azure">Microsoft Azure</a></td>
# <td id="mwcQ">2010</td>
# <td about="#mwt34" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwcg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt35" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwcw" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt36" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://docs.microsoft.com/en-us/azure/virtual-network/troubleshoot-outbound-smtp-connectivity SMTP] at Azure&lt;/ref&gt;"]}' id="mwdA" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt37" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-11"}}' id="cite_ref-11" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-11" id="mwdQ"><span class="mw-reflink-text" id="mwdg"><span class="cite-bracket" id="mwdw">[</span>11<span class="cite-bracket" id="mweA">]</span></span></a></sup></td>
# <td about="#mwt38" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mweQ" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt39" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://learn.microsoft.com/en-us/azure/security/fundamentals/overview Introduction to Azure security] at Azure&lt;/ref&gt;"]}' id="mweg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt40" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-12"}}' id="cite_ref-12" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-12" id="mwew"><span class="mw-reflink-text" id="mwfA"><span class="cite-bracket" id="mwfQ">[</span>12<span class="cite-bracket" id="mwfg">]</span></span></a></sup></td>
# <td id="mwfw">ca, us, br, ie, nl, de, uk, cn, au, jp, in, kr, sg, hk, za, id</td>
# <td id="mwgA">List of bugs<sup about="#mwt41" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-13"}}' id="cite_ref-13" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-13" id="mwgQ"><span class="mw-reflink-text" id="mwgg"><span class="cite-bracket" id="mwgw">[</span>13<span class="cite-bracket" id="mwhA">]</span></span></a></sup></td></tr>
# <tr id="mwhQ">
# <td id="mwhg"><a href="https://en.wikipedia.org/wiki/GoDaddy" id="mwhw" rel="mw:WikiLink" title="GoDaddy">GoDaddy</a></td>
# <td id="mwiA">2016</td>
# <td about="#mwt42" class="table-no" data-mw='{"parts":["| ",{"template":{"target":{"wt":"no","href":"./Template:No"},"params":{},"i":0}}]}' id="mwiQ" style="background:#FFC7C7;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">No</td>
# <td id="mwig"></td>
# <td id="mwiw"></td>
# <td about="#mwt43" class="table-no" data-mw='{"parts":["| ",{"template":{"target":{"wt":"no","href":"./Template:No"},"params":{},"i":0}}]}' id="mwjA" style="background:#FFC7C7;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">No</td>
# <td about="#mwt44" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://www.godaddy.com/web-security/website-security Website Security - Protect Your Site with GoDaddy]&lt;/ref&gt;"]}' id="mwjQ" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt45" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-14"}}' id="cite_ref-14" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-14" id="mwjg"><span class="mw-reflink-text" id="mwjw"><span class="cite-bracket" id="mwkA">[</span>14<span class="cite-bracket" id="mwkQ">]</span></span></a></sup></td>
# <td id="mwkg"></td>
# <td id="mwkw"></td></tr>
# <tr id="mwlA">
# <td id="mwlQ"><a class="mw-redirect" href="https://en.wikipedia.org/wiki/Rackspace" id="mwlg" rel="mw:WikiLink" title="Rackspace">Rackspace</a></td>
# <td id="mwlw">1998</td>
# <td about="#mwt46" class="table-partial" data-mw='{"parts":["| ",{"template":{"target":{"wt":"partial","href":"./Template:Partial"},"params":{},"i":0}}]}' id="mwmA" style="background:#FFB; color:black;vertical-align:middle;text-align:center; " typeof="mw:Transclusion">Partial</td>
# <td about="#mwt47" class="table-no" data-mw='{"parts":["| ",{"template":{"target":{"wt":"no","href":"./Template:No"},"params":{},"i":0}}]}' id="mwmQ" style="background:#FFC7C7;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">No</td>
# <td about="#mwt48" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwmg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt49" class="table-no" data-mw='{"parts":["| ",{"template":{"target":{"wt":"no","href":"./Template:No"},"params":{},"i":0}}]}' id="mwmw" style="background:#FFC7C7;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">No</td>
# <td about="#mwt50" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://www.rackspace.com/security Cloud Security &amp; Cybersecurity Solution]&lt;/ref&gt;"]}' id="mwnA" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt51" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-15"}}' id="cite_ref-15" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-15" id="mwnQ"><span class="mw-reflink-text" id="mwng"><span class="cite-bracket" id="mwnw">[</span>15<span class="cite-bracket" id="mwoA">]</span></span></a></sup></td>
# <td id="mwoQ">us, au, hk</td>
# <td id="mwog">root volume is a fixed size</td></tr>
# <tr id="mwow">
# <td id="mwpA"><a class="mw-redirect" href="https://en.wikipedia.org/wiki/OVH" id="mwpQ" rel="mw:WikiLink" title="OVH">OVH</a></td>
# <td id="mwpg">1999<sup about="#mwt54" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-16"}}' id="cite_ref-16" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-16" id="mwpw"><span class="mw-reflink-text" id="mwqA"><span class="cite-bracket" id="mwqQ">[</span>16<span class="cite-bracket" id="mwqg">]</span></span></a></sup></td>
# <td about="#mwt55" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwqw" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt56" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;{{Cite web|url=https://us.ovhcloud.com/products/networking/ip-failover|title=Failover IP - Networking &amp; Security {{!}} OVHcloud|last=|first=|date=2019-11-26|website=[[OVH]]|url-status=live|archive-url=https://archive.today/20191127003914/https://us.ovhcloud.com/products/networking/ip-failover|archive-date=2019-11-27|access-date=2019-11-26}}&lt;/ref&gt;"]}' id="mwrA" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt60" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-17"}}' id="cite_ref-17" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-17" id="mwrQ"><span class="mw-reflink-text" id="mwrg"><span class="cite-bracket" id="mwrw">[</span>17<span class="cite-bracket" id="mwsA">]</span></span></a></sup></td>
# <td about="#mwt61" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;{{Cite web|url=https://docs.ovh.com/gb/en/emails/web_hosting_an_overview_of_ovh_email/|title=Getting started with an MX Plan solution {{!}} OVH Guides|last=|first=|date=2019-11-26|website=[[OVH]]|url-status=live|archive-url=https://archive.today/20191127004657/https://docs.ovh.com/gb/en/emails/web_hosting_an_overview_of_ovh_email/|archive-date=2019-11-27|access-date=2019-11-26}}&lt;/ref&gt;"]}' id="mwsQ" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt65" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-18"}}' id="cite_ref-18" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-18" id="mwsg"><span class="mw-reflink-text" id="mwsw"><span class="cite-bracket" id="mwtA">[</span>18<span class="cite-bracket" id="mwtQ">]</span></span></a></sup></td>
# <td about="#mwt66" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwtg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt67" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://www.ovhcloud.com/en/security/ Network security and application protection | OVHcloud]&lt;/ref&gt;"]}' id="mwtw" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt68" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-19"}}' id="cite_ref-19" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-19" id="mwuA"><span class="mw-reflink-text" id="mwuQ"><span class="cite-bracket" id="mwug">[</span>19<span class="cite-bracket" id="mwuw">]</span></span></a></sup></td>
# <td id="mwvA">au, ca, de, fr, gb, pl, us, sg<sup about="#mwt72" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-20"}}' id="cite_ref-20" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-20" id="mwvQ"><span class="mw-reflink-text" id="mwvg"><span class="cite-bracket" id="mwvw">[</span>20<span class="cite-bracket" id="mwwA">]</span></span></a></sup></td>
# <td id="mwwQ"></td></tr>
# <tr id="mwwg">
# <td id="mwww"><a class="mw-redirect" href="https://en.wikipedia.org/wiki/Atlantic.Net" id="mwxA" rel="mw:WikiLink" title="Atlantic.Net">Atlantic.Net</a></td>
# <td id="mwxQ">2010</td>
# <td about="#mwt73" class="table-no" data-mw='{"parts":["| ",{"template":{"target":{"wt":"no","href":"./Template:No"},"params":{},"i":0}}]}' id="mwxg" style="background:#FFC7C7;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">No</td>
# <td id="mwxw"></td>
# <td about="#mwt74" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwyA" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt75" class="table-no" data-mw='{"parts":["| ",{"template":{"target":{"wt":"no","href":"./Template:No"},"params":{},"i":0}}]}' id="mwyQ" style="background:#FFC7C7;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">No</td>
# <td about="#mwt76" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://www.atlantic.net/pci-compliant-hosting/pci-security-services/ PCI Security Services]&lt;/ref&gt;"]}' id="mwyg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt77" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-21"}}' id="cite_ref-21" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-21" id="mwyw"><span class="mw-reflink-text" id="mwzA"><span class="cite-bracket" id="mwzQ">[</span>21<span class="cite-bracket" id="mwzg">]</span></span></a></sup></td>
# <td id="mwzw">us, uk, ca</td>
# <td id="mw0A"></td></tr>
# <tr id="mw0Q">
# <td id="mw0g"><a class="mw-redirect" href="https://en.wikipedia.org/wiki/Online_SAS" id="mw0w" rel="mw:WikiLink" title="Online SAS">Scaleway</a></td>
# <td id="mw1A">2016</td>
# <td about="#mwt78" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mw1Q" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt79" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;{{Cite web|url=https://www.scaleway.com/en/docs/deal-with-private-flexible-ips/#-Flexible-IPs|title=How to deal with private and flexible IPs addresses|last=|first=|date=2020-04-15|website=[[Scaleway]]}}&lt;/ref&gt;"]}' id="mw1g" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt82" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-22"}}' id="cite_ref-22" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-22" id="mw1w"><span class="mw-reflink-text" id="mw2A"><span class="cite-bracket" id="mw2Q">[</span>22<span class="cite-bracket" id="mw2g">]</span></span></a></sup></td>
# <td about="#mwt83" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://www.scaleway.com/en/faq/why-can-i-not-send-any-email/ SMTP] at Scaleway&lt;/ref&gt;"]}' id="mw2w" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt84" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-23"}}' id="cite_ref-23" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-23" id="mw3A"><span class="mw-reflink-text" id="mw3Q"><span class="cite-bracket" id="mw3g">[</span>23<span class="cite-bracket" id="mw3w">]</span></span></a></sup></td>
# <td about="#mwt85" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mw4A" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt86" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://www.scaleway.com/en/security-and-resilience/ Our certifications &amp; security]&lt;/ref&gt;"]}' id="mw4Q" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt87" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-24"}}' id="cite_ref-24" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-24" id="mw4g"><span class="mw-reflink-text" id="mw4w"><span class="cite-bracket" id="mw5A">[</span>24<span class="cite-bracket" id="mw5Q">]</span></span></a></sup></td>
# <td id="mw5g">fr, nl</td>
# <td id="mw5w"></td></tr>
# <tr id="mw6A">
# <td id="mw6Q"><a href="https://en.wikipedia.org/wiki/Alibaba_Cloud" id="mw6g" rel="mw:WikiLink" title="Alibaba Cloud">Alibaba Cloud</a></td>
# <td id="mw6w">2009</td>
# <td about="#mwt88" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mw7A" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt89" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mw7Q" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt90" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mw7g" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt91" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mw7w" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt92" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://www.alibabacloud.com/solutions/security Cloud Security]&lt;/ref&gt;"]}' id="mw8A" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt93" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-25"}}' id="cite_ref-25" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-25" id="mw8Q"><span class="mw-reflink-text" id="mw8g"><span class="cite-bracket" id="mw8w">[</span>25<span class="cite-bracket" id="mw9A">]</span></span></a></sup></td>
# <td id="mw9Q">cn, hk, sg, au, my, id, in, jp, us, de, uk, ae</td>
# <td id="mw9g"></td></tr>
# <tr id="mw9w">
# <td id="mw-A"><a href="https://en.wikipedia.org/wiki/Hetzner" id="mw-Q" rel="mw:WikiLink" title="Hetzner">Hetzner Cloud</a></td>
# <td id="mw-g"></td>
# <td about="#mwt94" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mw-w" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td id="mw_A"></td>
# <td id="mw_Q"></td>
# <td id="mw_g"></td>
# <td about="#mwt95" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://docs.hetzner.com/konsoleh/storage-share/faq/security/ Security]&lt;/ref&gt;"]}' id="mw_w" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt96" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-26"}}' id="cite_ref-26" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-26" id="mwAQA"><span class="mw-reflink-text" id="mwAQE"><span class="cite-bracket" id="mwAQI">[</span>26<span class="cite-bracket" id="mwAQM">]</span></span></a></sup></td>
# <td id="mwAQQ">de, fi, us, sg</td>
# <td id="mwAQU"></td></tr>
# <tr id="mwAQY">
# <td id="mwAQc"><a href="https://en.wikipedia.org/wiki/Safe_Swiss_Cloud" id="mwAQg" rel="mw:WikiLink" title="Safe Swiss Cloud">Safe Swiss Cloud</a></td>
# <td id="mwAQk">2013<sup about="#mwt97" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-27"}}' id="cite_ref-27" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-27" id="mwAQo"><span class="mw-reflink-text" id="mwAQs"><span class="cite-bracket" id="mwAQw">[</span>27<span class="cite-bracket" id="mwAQ0">]</span></span></a></sup></td>
# <td about="#mwt98" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwAQ4" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt99" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwAQ8" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td id="mwARA"></td>
# <td about="#mwt100" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwARE" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt101" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}},"&lt;ref&gt;[https://safeswisscloud.com/en/blog/category/it-security/ IT Security]&lt;/ref&gt;"]}' id="mwARI" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt102" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-28"}}' id="cite_ref-28" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-28" id="mwARM"><span class="mw-reflink-text" id="mwARQ"><span class="cite-bracket" id="mwARU">[</span>28<span class="cite-bracket" id="mwARY">]</span></span></a></sup></td>
# <td id="mwARc">ch</td>
# <td id="mwARg"></td></tr>
# <tr id="mwARk">
# <td id="mwARo"><a href="https://en.wikipedia.org/wiki/DigitalOcean" id="mwARs" rel="mw:WikiLink" title="DigitalOcean">DigitalOcean</a></td>
# <td id="mwARw">2016<sup about="#mwt103" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-29"}}' id="cite_ref-29" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-29" id="mwAR0"><span class="mw-reflink-text" id="mwAR4"><span class="cite-bracket" id="mwAR8">[</span>29<span class="cite-bracket" id="mwASA">]</span></span></a></sup></td>
# <td about="#mwt104" class="table-partial" data-mw='{"parts":["| ",{"template":{"target":{"wt":"partial","href":"./Template:Partial"},"params":{},"i":0}}]}' id="mwASE" style="background:#FFB; color:black;vertical-align:middle;text-align:center; " typeof="mw:Transclusion">Partial</td>
# <td about="#mwt105" class="table-yes" data-mw='{"parts":["| ",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwASI" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt106" class="table-partial" data-mw='{"parts":["| ",{"template":{"target":{"wt":"partial","href":"./Template:Partial"},"params":{},"i":0}}]}' id="mwASM" style="background:#FFB; color:black;vertical-align:middle;text-align:center; " typeof="mw:Transclusion">Partial</td>
# <td id="mwASQ"></td>
# <td about="#mwt107" class="table-yes" data-mw="{&quot;parts&quot;:[&quot;| &quot;,{&quot;template&quot;:{&quot;target&quot;:{&quot;wt&quot;:&quot;yes&quot;,&quot;href&quot;:&quot;./Template:Yes&quot;},&quot;params&quot;:{},&quot;i&quot;:0}},&quot;&lt;ref&gt;[https://www.digitalocean.com/security DigitalOcean's security pillars]&lt;/ref&gt;&quot;]}" id="mwASU" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes<sup about="#mwt108" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-30"}}' id="cite_ref-30" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-30" id="mwASY"><span class="mw-reflink-text" id="mwASc"><span class="cite-bracket" id="mwASg">[</span>30<span class="cite-bracket" id="mwASk">]</span></span></a></sup></td>
# <td id="mwASo">sg, nl, uk, ca, de, in</td>
# <td id="mwASs">SMTP for accounts older than 60 days<sup about="#mwt109" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-31"}}' id="cite_ref-31" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-31" id="mwASw"><span class="mw-reflink-text" id="mwAS0"><span class="cite-bracket" id="mwAS4">[</span>31<span class="cite-bracket" id="mwAS8">]</span></span></a></sup> but they use spam mandrillapp servers.<sup about="#mwt112" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-32"}}' id="cite_ref-32" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-32" id="mwATA"><span class="mw-reflink-text" id="mwATE"><span class="cite-bracket" id="mwATI">[</span>32<span class="cite-bracket" id="mwATM">]</span></span></a></sup> root volume is a fixed size.</td></tr>
# <tr id="mwATQ">
# <td id="mwATU"><a class="external text" href="https://www.blackboxhosting.co.uk/" id="mwATY" rel="mw:ExtLink nofollow">BlackBox Hosting</a></td>
# <td id="mwATc">2013</td>
# <td about="#mwt113" class="table-yes" data-mw='{"parts":["|",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwATg" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt114" class="table-yes" data-mw='{"parts":["|",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwATk" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt115" class="table-yes" data-mw='{"parts":["|",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwATo" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt116" class="table-yes" data-mw='{"parts":["|",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwATs" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td about="#mwt117" class="table-yes" data-mw='{"parts":["|",{"template":{"target":{"wt":"yes","href":"./Template:Yes"},"params":{},"i":0}}]}' id="mwATw" style="background:#9EFF9E;color:black;vertical-align:middle;text-align:center;" typeof="mw:Transclusion">Yes</td>
# <td id="mwAT0">uk</td>
# <td id="mwAT4"></td></tr>
# </tbody></table>

# %% [markdown]
# - `table`              → variable holding what **soup.find()** returns (the <table> block, or None)
# - `soup.find(...)`     → searches the parsed page for the first tag matching what we specify
# - `'table'`            → the HTML tag type we're looking for
# - `{'class': ...}`     → narrows the search to only tables labeled 'wikitable'
#                      (a page can have many tables; class filters out the wrong ones)
# - `is not None`        → quick check: did we actually find a match, or come up empty

# %%
# Find all the table rows inside the table
rows = table.find_all('tr')

# Check lengths of rows we got
print(len(rows))
# Out:
# 16

# %% [markdown]
# **What's happening:** in HTML, a table is built from `<tr>` (table row) tags, and each row contains `<td> `(data cell) or `<th>` (header cell) tags. **`find_all('tr')`** grabs every row in the table, not just the first one like `find()` did, so we get a list back instead of a single item.

# %%
# Loop through every row and grab the text from each cell

data = []
for row in rows:
    cols = row.find_all('td')                   # get all data cells in this row
    cols = [col.text.strip() for col in cols]  # extract text, remove whitespace
    if cols:
        data.append(cols)
        
# Check the first couple of extracted rows
print(data[:2])
# Out:
# [['Google Cloud Platform', '2013', 'Yes', 'No', 'No[1]', 'Yes', 'Yes[2]', 'br, ca, cl, us, be, ch, de, es, fi, it, po, nl, uk, il, au, cn, in, jp, sg, id, tw[3]', 'SMTP blocked.[4]'], ['Oracle Cloud', '2014', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes[5]', 'us, ca, br, de, uk, nl, ch, in, aus, jp, kr, saud', '']]

# %% [markdown]
# **What's happening, line by line:**
#
# - `data = []` — an empty list to collect our cleaned-up rows.
# - `for row in rows:` — go through each `<tr>` we found earlier, one at a time.
# - `row.find_all('td')` — inside this one row, find all `<td>` (data cell) tags. Note: header rows use `<th>` not `<td>`, so this naturally skips the header row's cells.
# - `col.text.strip()` — `.text` pulls just the visible text out of each cell (stripping away HTML tags), `.strip()` removes leading/trailing whitespace and newlines that HTML often leaves behind.
# - `if cols:` — if a row had no `<td>` cells (like the header row, which only has `<th>`), `cols` would be an empty list, this skips adding it.
# - `data.append(cols)` — add this row's cleaned data to our master list.
# ---
#
#
#
# **A simplified map of what a real HTML table looks like**
#
# ```html
# <table class="wikitable">
#   <tr>                          <!-- this is the HEADER row -->
#     <th>Provider</th>
#     <th>Founded</th>
#     <th>Free tier</th>
#   </tr>
#   <tr>                          <!-- this is a DATA row -->
#     <td>Google Cloud Platform</td>
#     <td>2013</td>
#     <td>Yes</td>
#   </tr>
#   <tr>                          <!-- another DATA row -->
#     <td>Oracle Cloud</td>
#     <td>2014</td>
#     <td>Yes</td>
#   </tr>
# </table>
# ```
#
# **How this maps to your variables:**
#
# ```
# <table>   →  table          (the whole thing)
# <tr>      →  one item in rows       (one row, header or data)
# <th>      →  header cell (skipped, since we only grabbed <td>)
# <td>      →  one item in cols       (one data cell inside a row)
# ```

# %%
# Header row is the first row in our table
header_row = rows[0]

# Grab the header cells (th, not td) and extract clean text 
header_list = [th.text.strip() for th in header_row.find_all('th')]

print(header_list)
# Out:
# ['Provider', 'Launched', 'Block storage', 'Assignable IPs', 'SMTP support', 'IOPS Guaranteed minimum', 'Security', 'Locations', 'Notes']

# %%
# Sanity check

# Print row 0 (should be the header)
print("ROW 0: ", [cell.text.strip() for cell in rows[0].find_all(['th', 'td'])])

# Print row 1 (should be the first data row)
print("ROW 1: ", [cell.text.strip() for cell in rows[1].find_all(['th', 'td'])])
# Out:
# ROW 0:  ['Provider', 'Launched', 'Block storage', 'Assignable IPs', 'SMTP support', 'IOPS Guaranteed minimum', 'Security', 'Locations', 'Notes']
# ROW 1:  ['Google Cloud Platform', '2013', 'Yes', 'No', 'No[1]', 'Yes', 'Yes[2]', 'br, ca, cl, us, be, ch, de, es, fi, it, po, nl, uk, il, au, cn, in, jp, sg, id, tw[3]', 'SMTP blocked.[4]']

# %%
# Turn our list of rows into a proper table using pandas
df = pd.DataFrame(data, columns=header_list)

df.head()
# Out:
#                 Provider Launched Block storage Assignable IPs SMTP support  \
# 0  Google Cloud Platform     2013           Yes             No        No[1]
# 1           Oracle Cloud     2014           Yes            Yes          Yes
# 2    Amazon Web Services     2006           Yes            Yes   Partial[6]
# 3              IBM Cloud     2005           Yes            Yes        No[9]
# 4        Microsoft Azure     2010           Yes            Yes      Yes[11]
#
#   IOPS Guaranteed minimum Security  \
# 0                     Yes   Yes[2]
# 1                     Yes   Yes[5]
# 2                     Yes   Yes[7]
# 3                     Yes  Yes[10]
# 4                     Yes  Yes[12]
#
#                                            Locations             Notes
# 0  br, ca, cl, us, be, ch, de, es, fi, it, po, nl...  SMTP blocked.[4]
# 1  us, ca, br, de, uk, nl, ch, in, aus, jp, kr, saud
# 2  us, ca, br, ie, de, uk, cn, sg, au, jp, kr, in...   List of bugs[8]
# 3  us, gb, fr, de, nl, in, au, hk, kr, it, jp, no...
# 4  ca, us, br, ie, nl, de, uk, cn, au, jp, in, kr...  List of bugs[13]

# %% [markdown]
# #### **4.2.1 Advanced Web Scraping - Downloading Files**
#
# **`<a>` tag (anchor tag)**
# Creates a clickable link on a webpage. Anything you've ever clicked to open a page or download a file was an `<a>` tag.
# ```html
# <a href="report.pdf">Download</a>
# ```
#
# **href**
# The attribute inside an `<a>` tag that holds the actual link destination.
# `<a href="report.pdf">Download</a>` → `href` = `"report.pdf"`
#
# **Relative vs Full URL**
# - Relative: `/files/report.pdf` (needs the site attached to work)
# - Full: `https://example.com/files/report.pdf` (works alone)
#
# **Why we check status code before saving**
# A failed or blocked request can still return content, sometimes an error page instead of the actual file. Checking `response.status_code == 200` before writing to disk avoids saving a broken file that looks fine until you try to open it.
#
#
# - `<a>` stands for anchor. It's the tag used to create hyperlinks. The actual destination lives in its `href` attribute (hypertext reference).
# ---

# %% [markdown]
# #### **Document Scraper**
#
# Extent the scraper to find and download an actual file (PDF/doc) instead of just table data.
#
# **We will be using this website for our work:**
#
# It's the **U.S. Internal Revenue Service's** (the American tax authority) official page listing downloadable tax forms and publications, things like W-2s, 1040s, instruction booklets, all as PDFs.
#
# > https://www.irs.gov/downloads/irs-pdf
#
# **Steps:**
# 1. Send the request to the page and confirm the status 200.
# 2. Confirm the status 200.
# 3. Parse the raw html into BeautifulSoup
# 4. Look at that `<a>` tag itself first: does it have a useful class or is the href distinctive (e.g., ends in .pdf)?  ---> Yes(looked the code of website)
# 5. Check if the link is relative or full
#    - Relative: `/files/report.pdf`
#    - Full: `https://site.com/files/report.pdf`
# 5. Then zoom out, look at its parent elements, one level up (`<td>`), then further up (`<tr>`, then `<table>`), noting each one's class/id as you go
# 6. Fetch the stable parent identifier — **here:** `table class="cols-4"` (the `id` changes on every reload, don't use it)
# 7. Loop through rows, extract the `<a>` tag whose `href` ends in `.pdf`
# 8. Set up a folder to keeps PDFs

# %%
# Document scraper

# Import the required libraries
import requests
from bs4 import BeautifulSoup
from pathlib import Path


# Information for web scraping
url = 'https://www.irs.gov/downloads/irs-pdf'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/151.0.0.0 Safari/537.36'
}

# Step1: Send the request to the page 
response = requests.get(url=url, headers=headers)

# Step 2: Confirm the status 200.
if response.status_code==200:
    print(f"Connection successful: {response.status_code}")
else:
    print(f"Failed to retrieve the webpage: {response.status_code}")
    exit()  # Exit the program   
    
    
# Step 3: Parse the raw html into beautifulsoup
soup =  BeautifulSoup(response.content, 'html.parser')
print(f"Title: {soup.title.text}")
# Out:
# Connection successful: 200
# Title: Irs-pdf | Internal Revenue Service

# %%
# Step 4: Look at that <a> tag itself first: does it have a useful class or is the href distinctive (e.g., ends in .pdf)?  ---> Yes.(looked the code of website)
# Step 5: Full path is available
# Step 6: Fetch the stable parent identifier — **here:** `table class="cols-4"` (the `id` changes on every reload, don't use it)

table = soup.find('table', {'class' : 'cols-4'})
print(table is not None)

# Step 7 : Loop through rows, extract the `<a>` tag whose `href` ends in `.pdf`
rows = table.find_all('tr')
print(len(rows))

pdf_links = []
for row in rows[1:]: # [1:] skips row 0, the header row
    link_tag = row.find('a', href=lambda href: href and href.endswith('.pdf'))
    if link_tag:
        pdf_links.append(link_tag['href'])

print(len(pdf_links))
print(pdf_links[:3])
# Out:
# True
# 51
# 50
# ['https://www.irs.gov/pub/irs-pdf/fw2.pdf', 'https://www.irs.gov/pub/irs-pdf/fw2gu.pdf', 'https://www.irs.gov/pub/irs-pdf/fw2vi.pdf']

# %%
# # Step 8: Set up a folder to keeps PDFs
# import os

# pdf_folder = Path("../module_1/pdf_folder")
# os.makedirs(pdf_folder, exist_ok=True)


# # Step 9: Loop through and pdf link list
# for i, link in enumerate(pdf_links):
#     response = requests.get(link, headers=headers)
#     if response.status_code==200:
#         filepath = pdf_folder / f'pdf_{i}.pdf'
#         if not filepath.exists():
#             with open(filepath, "wb") as file:
#                     file.write(response.content)
#         else:
#             print(f"Skipped (already exists): {filepath}")
#     else:
#             print(f"Error Encountered - link: {link}: {response.status_code}")
# Out:
# Skipped (already exists): ../module_1/pdf_folder/pdf_0.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_1.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_2.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_3.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_4.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_5.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_6.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_7.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_8.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_9.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_10.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_11.pdf
# Skipped (already exists): ../module_1/pdf_folder/pdf_12.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 10
#       6
#       7
#       8 # Step 9: Loop through and pdf link list
#       9 for i, link in enumerate(pdf_links):
# ---> 10     response = requests.get(link, headers=headers)
#      11     if response.status_code==200:
#      12         filepath = pdf_folder / f'pdf_{i}.pdf'
#      13         if not filepath.exists():
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/requests/api.py:87, in get(url, params, **kwargs)
#      74 def get(
#      75     url: _t.UriType, params: _t.ParamsType = None, **kwargs: Unpack[_t.GetKwargs]
#      76 ) -> Response:
#      77     r"""Sends a GET request.
#      78
#      79     :param url: URL for the new :class:`Request` object.
#    (...)     84     :rtype: requests.Response
#      85     """
# ---> 87     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/requests/api.py:71, in request(method, url, **kwargs)
#      67 # By using the 'with' statement we are sure the session is closed, thus we
#      68 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      69 # cases, and look like a memory leak in others.
#      70 with sessions.Session() as session:
# ---> 71     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/requests/sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/requests/sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/requests/adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     693     resolved_timeout = TimeoutSauce(connect=timeout, read=timeout)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#     711     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/urllib3/connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785 response_conn = conn if not release_conn else None
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#     804 clean_exit = True
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/urllib3/connectionpool.py:1106, in HTTPSConnectionPool._validate_conn(self, conn)
#    1104 # Force connect early to allow us to validate the connection.
#    1105 if conn.is_closed:
# -> 1106     conn.connect()
#    1108 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1109 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/urllib3/connection.py:759, in HTTPSConnection.connect(self)
#     757 try:
#     758     sock: socket.socket | ssl.SSLSocket
# --> 759     self.sock = sock = self._new_conn()
#     760     server_hostname: str = self.host
#     761     tls_in_tls = False
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     199 """Establish a socket connection and set nodelay settings on it.
#     200
#     201 :return: New socket connection.
#     202 """
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#     211     raise NameResolutionError(self.host, self, e) from e
#
# File ~/miniconda3/envs/ms-ai-01/lib/python3.14/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:
